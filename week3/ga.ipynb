# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# partition([13, 18, 8, 10, 21, 7, 2, 32, 6, 19], 0, 9)
#
# low = 0
# i = 1
# j = 9
# up = 9
# pivot = 13
#
# #first
#
# #i < j True
# #L[i] < pivot  False
# #i =1
# #L[j] > pivot TRue
# #j = 8
# L = [13, 6, 8, 10, 21, 7, 2, 32, 18, 19]
# #i = 2
# #j = 7
#
# #second
# #i < j True
# #L[i] < pivot  TRue
# #i =3
# #L[j] > pivot TRue
# #j = 6
# L = [13, 6, 8, 2, 21, 7, 10, 32, 18, 19]
# #i = 3
# #j = 5
#
#
# #third
# #i < j True
# #L[i] < pivot  TRue
# #i =4
# #L[j] > pivot False
# #j = 5
# L = [13, 6, 8, 2, 7, 21, 10, 32, 18, 19]
# #i = 5
# #j = 4
