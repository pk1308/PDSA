# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import  Stack

def dosomething(Q, R):
    if (not Q.sempty()):
        v=Q.dequeue()
        doSomething(Q.)
        enqueue()
# Out:
#   Cell In[1], line 6
#     doSomething(Q.)
#                   ^
# SyntaxError: invalid syntax
