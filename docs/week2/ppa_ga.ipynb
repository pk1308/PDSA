# %% [markdown]
# ![image.png](attachment:image.png)
#
# [16, 53, 59, 81, 94, 99, 121, 150, 162, 170]
#
# [99, 121, 150, 162, 170]
#
# [99,121]

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [38, 28, 43, 22, 112, 33, 39]
#
# i = 0
# j = 0
#
# swap 0
# [38, 28, 43, 22, 112, 33, 39]
# i = 1
# j = 1
#
# swap 1
# [28, 38, 43, 22, 112, 33, 39]
# j = 0
#
# i = 2
# j = 2
#
# swap 1
# [28, 38, 43, 22, 112, 33, 39]
# j = 1
#
# [28, 38, 43, 22, 112, 33, 39]
# j = 0
#
# i = 3
# j = 3
#
# swap 2
# [28, 38, 22,43,  112, 33, 39]
# j = 2
# swap 3
# [28,22, 38,43,  112, 33, 39]
# j = 1
#
# swap 4
# [22,28, 38,43,  112, 33, 39]
# j = 0
#
# i = 4
# j = 4
#
# swap 4
# [22,28, 38,43,  112, 33, 39]
# j = 0
#
#
# i = 4
# j = 4
#
# swap 7
# [22,28,33, 38,43,  112,  39]
# j = 0
#
# i = 5
# j = 5
#
# swap 9
# [22,28,33, 38,43,  112,  39]
# j = 0

# %% [markdown]
# L1=[4,5,6]
#  L2=[1,2,3]
# L3=[7,9,11]
# L4  =[8,10,12]
#
# [1,2,3 , 4,5,6] = 3
#
# [7,8,9,10,11,12] = 5

# %% [markdown]
#  ![image.png](attachment:image.png)
#  [9, 4, 5, 2, 3, 7, 6, 8, 1]
#
#  n = 9
#  i = 0
#  mpos = 0
#
#  mpos = 1
#  mpos = 8
# [1, 4, 5, 2, 3, 7, 6, 8, 9]
# i = 1
# mpos = 1
#
# mpos =3
# [1, 2, 5, 4, 3, 7, 6, 8, 9]
#
# i = 2
# mpos = 2
#
# mpos = 4
# [1, 2, 3, 4, 5, 7, 6, 8, 9]
# i = 3
# mpos = 3
#
# nothing
#
# i = 4
# mpos = 4
#
# nothing
#
# i = 5
# mpos = 5
# [1, 2, 3, 4, 5,  6, 7,  8, 9]
